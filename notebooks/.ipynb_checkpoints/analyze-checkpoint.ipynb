# %%
# import pandas
import pandas as pd

# %%
# read your csv in
df = pd.read_csv('../data/covid-census.csv')
df
# Out:
#             date    county_x  state_x   fips  cases  deaths  DRRALL  CRRINT  \
# 0     2020-05-14     Autauga  Alabama   1001    104       4     0.2    52.5
# 1     2020-05-14     Baldwin  Alabama   1003    243       8     0.2    40.5
# 2     2020-05-14     Barbour  Alabama   1005     74       1     0.2    26.6
# 3     2020-05-14        Bibb  Alabama   1007     46       1     0.2    23.9
# 4     2020-05-14      Blount  Alabama   1009     45       0     0.3    38.0
# ...          ...         ...      ...    ...    ...     ...     ...     ...
# 2887  2020-05-14    Sublette  Wyoming  56035      3       0     0.1    13.6
# 2888  2020-05-14  Sweetwater  Wyoming  56037     21       0     0.1    47.5
# 2889  2020-05-14       Teton  Wyoming  56039     99       1     0.1    18.4
# 2890  2020-05-14       Uinta  Wyoming  56041      9       0     0.1    39.7
# 2891  2020-05-14    Washakie  Wyoming  56043      7       0     0.0    37.5
#
# ...
